# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns
from scipy import stats
from openpyxl import Workbook

# %%
df_new = pd.read_excel('./Тестовое data.xlsx', sheet_name = 'Group_Style_By_stats', skiprows = range(1,50))
df_old = pd.read_excel('./Тестовое data.xlsx', sheet_name = 'Group_Style_By_stats', skiprows = range(50,54))
# Out:
#         player     stat1     stat2  stat3     stat4     stat5  stat6  \
# 0  new_player1  0.000000  0.554217    NaN  0.201754  0.092466    NaN
# 1  new_player2  0.000000  0.523179    NaN  0.184261  0.100629    NaN
# 2  new_player3  0.000043  0.517135    NaN  0.198791  0.088291    NaN
# 3  new_player4  0.000000  0.425349    NaN  0.284902  0.045775    NaN
#
#       stat7  stat8     stat9  ...   stat118   stat119   stat120   stat121  \
# 0  0.550000    NaN  0.122222  ...  0.392911  0.187618  0.501706  0.267369
# 1  0.591027    NaN  0.090349  ...  0.459635  0.217386  0.326512  0.273698
# 2  0.637899    NaN  0.081690  ...  0.469933  0.220872  0.275281  0.268725
# 3  0.547669    NaN  0.045872  ...  0.431263  0.182633  0.440329  0.271261
#
#     stat122   stat123  stat124   stat125  stat126  stat127
# 0  0.165283  0.001663      NaN  0.237372      NaN      NaN
# 1  0.304442  0.007308      NaN  0.274538      NaN      NaN
# 2  0.288211  0.016889      NaN  0.263282      NaN      NaN
# ...

# %%
STD = df_new.std()
STD = [x for x in STD if pd.isnull(x) == False]
pl = sns.histplot(STD, color="dodgerblue", kde=True, bins = 127)
pl.set_ylabel('Statistics')
pl.set_xlabel('STD')

plt.grid()

# %%
STD2 = df_old.std()
STD2 = [x for x in STD2 if pd.isnull(x) == False]
pl2 = sns.histplot(STD2, color="dodgerblue", kde=True, bins = 127)
pl2.set_ylabel('Statistics')
pl2.set_xlabel('STD')

plt.grid()
